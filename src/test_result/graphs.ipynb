# %%
import os, sys
from datetime import datetime
sys.path.append(os.path.abspath('..'))
from callback.guest_callback_per_episode import CallbackPerEpisode
import numpy as np

# %%
train = CallbackPerEpisode()
date_str = datetime.now().strftime("%Y_%m_%d")
date_pkl = datetime.now().strftime("%Y%m%d")  
results_dir = os.path.join(os.getcwd(),f"train_result_{date_str}")
results_dir_pkl = os.path.join(os.getcwd(),f"train_result_{date_str}/train_{date_pkl}.pkl")

# %%
data = train.load_data(results_dir_pkl)
# Out:
# Callback data loaded from /Users/ofir/env/src/test_result/train_result_2025_10_05/train_20251005.pkl

# %%
from datetime import datetime
date_str = datetime.now().strftime("%Y_%m_%d")
os.makedirs(f"{results_dir}/train_result_{date_str}", exist_ok=True)
os.makedirs(f"{results_dir}/summary_plot_{date_str}", exist_ok=True)

# %%
train._create_summary_plots(f"{results_dir}/summary_plot_{date_str}")

# %%
train._create_episode_plot_3(99, f"{results_dir}/train_result_{date_str}")
# Out:
# --------------
# {'rewards': [1.0, 1.0, 1.0, 0.33333334, 0.33333334, 0.33333334, 0.33333334, 0.33333334, 0.33333334, 0.33333334, 0.33333334, 0.33333334, 0.3939394, 0.44444445, 0.44444445, 0.5802469, 0.64444447, 0.67676765, 0.7037037, 0.72649574, 0.72649574, 0.74603176, 0.74814814, 0.74814814, 0.78723407, 0.78723407, 0.7777778, 0.75641024, 0.737003, 0.71929824, 0.70308125, 0.68817204, 0.6744186, 0.66169155, 0.66169155, 0.6761905, 0.6761905, 0.6761905, 0.6894977, 0.7017544, 0.71308017, 0.72357726, 0.73333335, 0.72727275, 0.71428573, 0.70212764, 0.69072163, 0.69072163, 0.7104377, 0.7293729, 0.7293729, 0.71794873, 0.71794873, 0.7071651, 0.6969697, 0.68731564, 0.68731564, 0.6940837, 0.700565, 0.70677733, 0.71273714, 0.7184595, 0.7239583, 0.7292465, 0.7292465, 0.7433962, 0.75712514, 0.7704518, 0.7833935, 0.7959668, 0.8081871, 0.8081871, 0.79839635, 0.79839635, 0.8101695, 0.8216277, 0.8327833, 0.8327833, 0.82308525, 0.8137566, 0.8047767, 0.7961264, 0.7877878, 0.7797443, 0.7719807, 0.76448244, 0.76448244, 0.75723624, 0.75723624, 0.7605893, 0.76385105, 0.7670251, 0.77011496, 0.77011496, 0.7731239, 0.7760551, 0.7789116, 0.7816961, 0.78441125, 0.7870598, 0.7870598, 0.7804681, 0.77406526, 0.7678431, 0.76179427, 0.7559115, 0.7501881, 0.74461764, 0.74461764, 0.74743026, 0.75018156, 0.75287354, 0.7555082, 0.7580872, 0.76061237, 0.7630854, 0.7655078, 0.7655078, 0.7678812, 0.7678812, 0.7678812, 0.7751004, 0.7822045, 0.7891963, 0.79607844, 0.80285347, 0.8095238, 0.8095238, 0.81609195, 0.8225602, 0.8289308, 0.8289308, 0.8305296, 0.8305296, 0.8305296, 0.8305296, 0.8250154, 0.81962216, 0.814346, 0.80918306, 0.8041298, 0.8041298, 0.7991827, 0.7991827, 0.8009