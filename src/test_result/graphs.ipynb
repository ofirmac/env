# %%
import os, sys
from datetime import datetime
sys.path.append(os.path.abspath('..'))
from callback.guest_callback_per_episode import CallbackPerEpisode
import numpy as np

# %%
train = CallbackPerEpisode()
date_str = datetime.now().strftime("%Y_%m_%d")
date_pkl = datetime.now().strftime("%Y%m%d")  
results_dir = os.path.join(os.getcwd(),f"train_result_{date_str}")
results_dir_pkl = os.path.join(os.getcwd(),f"train_result_{date_str}/train_{date_pkl}.pkl")

# %%
data = train.load_data(results_dir_pkl)
# Out:
# 2025-10-07 23:58:01.537 | INFO     | callback.guest_callback_per_episode:load_data:567 - Callback data loaded from /Users/ofir/env/src/test_result/train_result_2025_10_07/train_20251007.pkl

# %%
from datetime import datetime
date_str = datetime.now().strftime("%Y_%m_%d")
os.makedirs(f"{results_dir}/train_result_{date_str}", exist_ok=True)
os.makedirs(f"{results_dir}/summary_plot_{date_str}", exist_ok=True)

# %%
train._create_summary_plots(f"{results_dir}/summary_plot_{date_str}")

# %%
train._create_episode_plot(10, f"{results_dir}/train_result_{date_str}")
# Out:
# 2025-10-07 23:58:04.531 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 11

# %%
import os
for i in range(100):
    train._create_episode_plot(i, f"{results_dir}/train_result_{date_str}")
# Out:
# 2025-10-07 23:58:06.456 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 1
# 2025-10-07 23:58:08.417 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 2
# 2025-10-07 23:58:10.321 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 3
# 2025-10-07 23:58:12.327 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 4
# 2025-10-07 23:58:14.273 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 5
# 2025-10-07 23:58:16.192 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 6
# 2025-10-07 23:58:18.136 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 7
# 2025-10-07 23:58:20.042 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 8
# 2025-10-07 23:58:22.046 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 9
# 2025-10-07 23:58:23.962 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 10
# 2025-10-07 23:58:25.914 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 11
# 2025-10-07 23:58:27.874 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 12
# 2025-10-07 23:58:29.766 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 13
# 2025-10-07 23:58:31.678 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 14
# 2025-10-07 23:58:33.612 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 15
# 2025-10-07 23:58:35.734 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 16
# 2025-10-07 23:58:37.749 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 17
# 2025-10-07 23:58:39.810 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 18
# 2025-10-07 23:58:41.764 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 19
# 2025-10-07 23:58:43.747 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 20
# 2025-10-07 23:58:45.825 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 21
# 2025-10-07 23:58:47.819 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 22
# 2025-10-07 23:58:49.786 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 23
# 2025-10-07 23:58:51.874 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 24
# 2025-10-07 23:58:53.833 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 25
# 2025-10-07 23:58:55.761 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 26
# 2025-10-07 23:58:57.654 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 27
# 2025-10-07 23:58:59.572 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 28
# 2025-10-07 23:59:01.447 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 29
# 2025-10-07 23:59:03.349 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 30
# 2025-10-07 23:59:05.265 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 31
# 2025-10-07 23:59:07.207 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 32
# 2025-10-07 23:59:09.317 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 33
# 2025-10-07 23:59:11.240 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 34
# 2025-10-07 23:59:13.182 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 35
# 2025-10-07 23:59:15.138 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 36
# 2025-10-07 23:59:17.107 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 37
# 2025-10-07 23:59:19.072 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 38
# 2025-10-07 23:59:21.025 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 39
# 2025-10-07 23:59:22.961 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 40
# 2025-10-07 23:59:24.920 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 41
# 2025-10-07 23:59:26.884 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 42
# 2025-10-07 23:59:28.803 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 43
# 2025-10-07 23:59:30.716 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 44
# 2025-10-07 23:59:32.839 | INFO     | callback.guest_callback_per_episode:_create_episode_plot:445 - Saved plot for episode 45
